# %%
import pandas as pd
import numpy  as np

# %%
df = pd.read_csv('/Users/jonahwork/Downloads/index.csv')

# %%
df
# Out:
#      Year  Month  Day  Federal Funds Target Rate  Federal Funds Upper Target  \
# 0    1954      7    1                        NaN                         NaN
# 1    1954      8    1                        NaN                         NaN
# 2    1954      9    1                        NaN                         NaN
# 3    1954     10    1                        NaN                         NaN
# 4    1954     11    1                        NaN                         NaN
# ..    ...    ...  ...                        ...                         ...
# 899  2016     12   14                        NaN                        0.75
# 900  2017      1    1                        NaN                        0.75
# 901  2017      2    1                        NaN                        0.75
# 902  2017      3    1                        NaN                        0.75
# 903  2017      3   16                        NaN                        1.00
#
# ...

# %%
df = df[df['Year'] > 2010]
df = df[df['Year'] < 2019]
df
# Out:
#      Year  Month  Day  Federal Funds Target Rate  Federal Funds Upper Target  \
# 826  2011      1    1                        NaN                        0.25
# 827  2011      2    1                        NaN                        0.25
# 828  2011      3    1                        NaN                        0.25
# 829  2011      4    1                        NaN                        0.25
# 830  2011      5    1                        NaN                        0.25
# ..    ...    ...  ...                        ...                         ...
# 899  2016     12   14                        NaN                        0.75
# 900  2017      1    1                        NaN                        0.75
# 901  2017      2    1                        NaN                        0.75
# 902  2017      3    1                        NaN                        0.75
# 903  2017      3   16                        NaN                        1.00
#
# ...

# %%
yearly_df = df.groupby('Year').mean()

# %%
yearly_df
# Out:
#          Month       Day  Federal Funds Target Rate  \
# Year
# 2011  6.500000  1.000000                        NaN
# 2012  6.500000  1.000000                        NaN
# 2013  6.500000  1.000000                        NaN
# 2014  6.500000  1.000000                        NaN
# 2015  6.923077  2.153846                        NaN
# 2016  6.923077  2.000000                        NaN
# 2017  2.250000  4.750000                        NaN
#
#       Federal Funds Upper Target  Federal Funds Lower Target  \
# Year
# 2011                    0.250000                    0.000000
# 2012                    0.250000                    0.000000
# 2013                    0.250000                    0.000000
# 2014                    0.250000                    0.000000
# 2015                    0.269231                    0.019231
# 2016                    0.519231                    0.269231
# 2017                    0.812500                    0.562500
#
# ...

# %%
yearly_df = yearly_df.reset_index()

# %%
pull2018 = yearly_df[yearly_df['Year'] == 2017]

# %%
pull2018
# Out:
#    Year  Month   Day  Federal Funds Target Rate  Federal Funds Upper Target  \
# 6  2017   2.25  4.75                        NaN                      0.8125
#
#    Federal Funds Lower Target  Effective Federal Funds Rate  \
# 6                      0.5625                         0.655
#
#    Real GDP (Percent Change)  Unemployment Rate  Inflation Rate
# 6                        NaN               4.75            2.25

# %%
pull2018['Year'] = 2018
# Out:
# <ipython-input-44-b714a01210e0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pull2018['Year'] = 2018

# %%
pull2018
# Out:
#    Year  Month   Day  Federal Funds Target Rate  Federal Funds Upper Target  \
# 6  2018   2.25  4.75                        NaN                      0.8125
#
#    Federal Funds Lower Target  Effective Federal Funds Rate  \
# 6                      0.5625                         0.655
#
#    Real GDP (Percent Change)  Unemployment Rate  Inflation Rate
# 6                        NaN               4.75            2.25

# %%
yearly_df = pd.concat([yearly_df, pull2018])

# %%
yearly_df
# Out:
#    Year     Month       Day  Federal Funds Target Rate  \
# 0  2011  6.500000  1.000000                        NaN
# 1  2012  6.500000  1.000000                        NaN
# 2  2013  6.500000  1.000000                        NaN
# 3  2014  6.500000  1.000000                        NaN
# 4  2015  6.923077  2.153846                        NaN
# 5  2016  6.923077  2.000000                        NaN
# 6  2017  2.250000  4.750000                        NaN
# 6  2018  2.250000  4.750000                        NaN
#
#    Federal Funds Upper Target  Federal Funds Lower Target  \
# 0                    0.250000                    0.000000
# 1                    0.250000                    0.000000
# 2                    0.250000                    0.000000
# 3                    0.250000                    0.000000
# 4                    0.269231                    0.019231
# 5                    0.519231                    0.269231
# ...

# %%
yearly_df.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Federal Funds Target Rate',
#        'Federal Funds Upper Target', 'Federal Funds Lower Target',
#        'Effective Federal Funds Rate', 'Real GDP (Percent Change)',
#        'Unemployment Rate', 'Inflation Rate'],
#       dtype='object')

# %%
yearly_df = yearly_df.drop(columns = ['Month', 'Day', 'Federal Funds Target Rate',
       'Federal Funds Upper Target', 'Federal Funds Lower Target',
       'Real GDP (Percent Change)',
       'Unemployment Rate', 'Inflation Rate'], axis = 1)

# %%
yearly_df
# Out:
#    Year  Effective Federal Funds Rate
# 0  2011                      0.101667
# 1  2012                      0.140000
# 2  2013                      0.107500
# 3  2014                      0.089167
# 4  2015                      0.132500
# 5  2016                      0.395000
# 6  2017                      0.655000
# 6  2018                      0.655000

# %%
df = pd.read_csv('/Users/jonahwork/Documents/united-states-gdp-growth-rate.csv')

# %%
df
# Out:
#           date   GDP Growth (%)   Annual Change
# 0   1961-12-31           2.3000             NaN NaN
# 1   1962-12-31           6.1000            3.80 NaN
# 2   1963-12-31           4.4000           -1.70 NaN
# 3   1964-12-31           5.8000            1.40 NaN
# 4   1965-12-31           6.4000            0.60 NaN
# 5   1966-12-31           6.5000            0.10 NaN
# 6   1967-12-31           2.5000           -4.00 NaN
# 7   1968-12-31           4.8000            2.30 NaN
# 8   1969-12-31           3.1000           -1.70 NaN
# 9   1970-12-31          -0.4105           -3.51 NaN
# 10  1971-12-31           3.2934            3.70 NaN
# 11  1972-12-31           5.2589            1.97 NaN
# 12  1973-12-31           5.6457            0.39 NaN
# 13  1974-12-31          -0.5405           -6.19 NaN
# 14  1975-12-31          -0.2055            0.34 NaN
# 15  1976-12-31           5.3881            5.59 NaN
# 16  1977-12-31           4.6242           -0.76 NaN
# ...

# %%
df['Year'] = df['date'].str[:4].astype(int)

# %%
df
# Out:
#           date   GDP Growth (%)   Annual Change      Year
# 0   1961-12-31           2.3000             NaN NaN  1961
# 1   1962-12-31           6.1000            3.80 NaN  1962
# 2   1963-12-31           4.4000           -1.70 NaN  1963
# 3   1964-12-31           5.8000            1.40 NaN  1964
# 4   1965-12-31           6.4000            0.60 NaN  1965
# 5   1966-12-31           6.5000            0.10 NaN  1966
# 6   1967-12-31           2.5000           -4.00 NaN  1967
# 7   1968-12-31           4.8000            2.30 NaN  1968
# 8   1969-12-31           3.1000           -1.70 NaN  1969
# 9   1970-12-31          -0.4105           -3.51 NaN  1970
# 10  1971-12-31           3.2934            3.70 NaN  1971
# 11  1972-12-31           5.2589            1.97 NaN  1972
# 12  1973-12-31           5.6457            0.39 NaN  1973
# 13  1974-12-31          -0.5405           -6.19 NaN  1974
# 14  1975-12-31          -0.2055            0.34 NaN  1975
# ...

# %%
df_final = yearly_df.merge(df, how = 'left', on = 'Year')

# %%
df_final
# Out:
#    Year  Effective Federal Funds Rate        date   GDP Growth (%)  \
# 0  2011                      0.101667  2011-12-31           1.5508
# 1  2012                      0.140000  2012-12-31           2.2495
# 2  2013                      0.107500  2013-12-31           1.8421
# 3  2014                      0.089167  2014-12-31           2.5260
# 4  2015                      0.132500  2015-12-31           3.0755
# 5  2016                      0.395000  2016-12-31           1.7114
# 6  2017                      0.655000  2017-12-31           2.3327
# 7  2018                      0.655000  2018-12-31           2.9965
#
#     Annual Change
# 0           -1.01 NaN
# 1            0.70 NaN
# 2           -0.41 NaN
# 3            0.68 NaN
# 4            0.55 NaN
# 5           -1.36 NaN
# 6            0.62 NaN
# 7            0.66 NaN

# %%
df_final.columns
# Out:
# Index(['Year', 'Effective Federal Funds Rate', 'date', ' GDP Growth (%)',
#        ' Annual Change', ' '],
#       dtype='object')

# %%
df_final = df_final.drop(columns = [' ', 'date'])

# %%
df_final
# Out:
#    Year  Effective Federal Funds Rate   GDP Growth (%)   Annual Change
# 0  2011                      0.101667           1.5508           -1.01
# 1  2012                      0.140000           2.2495            0.70
# 2  2013                      0.107500           1.8421           -0.41
# 3  2014                      0.089167           2.5260            0.68
# 4  2015                      0.132500           3.0755            0.55
# 5  2016                      0.395000           1.7114           -1.36
# 6  2017                      0.655000           2.3327            0.62
# 7  2018                      0.655000           2.9965            0.66
